# %%
import pandas as pd
from sklearn.model_selection  import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
data = pd.read_csv("../data/guardian/knn_model/final_files/1476371065-100-train.csv")

x = data.iloc[:,1:]
y = data.iloc[:,0:1].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)
n_neighbors = 11
neigh = KNeighborsClassifier(n_neighbors, weights='distance')
neigh.fit(X_train, y_train)
y_pred = neigh.predict(x)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
# Out:
# [[  878     2]
#  [    2 16858]]
#               precision    recall  f1-score   support
#
#       attack       1.00      1.00      1.00       880
#       normal       1.00      1.00      1.00     16860
#
#     accuracy                           1.00     17740
#    macro avg       1.00      1.00      1.00     17740
# weighted avg       1.00      1.00      1.00     17740

# %%
data2 = pd.read_csv("../data/guardian/knn_model/final_files/1476371065-100.csv")

x2 = data2.iloc[:,1:]
y2 = data2.iloc[:,0:1]

y_pred = neigh.predict(x2)
print(confusion_matrix(y2,y_pred))
print(classification_report(y2,y_pred))
# Out:
# [[  85  135]
#  [  16 4204]]
#               precision    recall  f1-score   support
#
#       attack       0.84      0.39      0.53       220
#       normal       0.97      1.00      0.98      4220
#
#     accuracy                           0.97      4440
#    macro avg       0.91      0.69      0.76      4440
# weighted avg       0.96      0.97      0.96      4440

# %%
data = pd.read_csv("../data/guardian/knn_model/final_files/1122809848-100_train.csv")

x = data.iloc[:,1:]
y = data.iloc[:,0:1].values.ravel()


# y_pred = neigh.predict(x)
# print(confusion_matrix(y,y_pred))
# print(classification_report(y,y_pred))

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

n_neighbors = 11
neigh = KNeighborsClassifier(n_neighbors, weights='distance')
neigh.fit(X_train, y_train)
y_pred = neigh.predict(x)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
# Out:
# [[5499   91]
#  [  31 5339]]
#               precision    recall  f1-score   support
#
#       attack       0.99      0.98      0.99      5590
#       normal       0.98      0.99      0.99      5370
#
#     accuracy                           0.99     10960
#    macro avg       0.99      0.99      0.99     10960
# weighted avg       0.99      0.99      0.99     10960

# %% [markdown]
# ## test

# %%
data2 = pd.read_csv("../data/guardian/knn_model/final_files/1122809848-100_test.csv")

x2 = data2.iloc[:,1:]
y2 = data2.iloc[:,0:1]

y_pred = neigh.predict(x2)
print(confusion_matrix(y2,y_pred))
print(classification_report(y2,y_pred))
# Out:
# [[ 579   11]
#  [ 836 9644]]
#               precision    recall  f1-score   support
#
#       attack       0.41      0.98      0.58       590
#       normal       1.00      0.92      0.96     10480
#
#     accuracy                           0.92     11070
#    macro avg       0.70      0.95      0.77     11070
# weighted avg       0.97      0.92      0.94     11070

# %%
data = pd.read_csv("../data/guardian/knn_model/final_files/1160238839-100-train.csv")

x = data.iloc[:,1:]
y = data.iloc[:,0:1].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

n_neighbors = 11
neigh = KNeighborsClassifier(n_neighbors, weights='distance')
neigh.fit(X_train, y_train)
y_pred = neigh.predict(x)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
# Out:
# [[  876     4]
#  [    0 16860]]
#               precision    recall  f1-score   support
#
#       attack       1.00      1.00      1.00       880
#       normal       1.00      1.00      1.00     16860
#
#     accuracy                           1.00     17740
#    macro avg       1.00      1.00      1.00     17740
# weighted avg       1.00      1.00      1.00     17740

# %%
data2 = pd.read_csv("../data/guardian/knn_model/final_files/1160238839-100.csv")

x2 = data2.iloc[:,1:]
y2 = data2.iloc[:,0:1]

y_pred = neigh.predict(x2)
print(confusion_matrix(y2,y_pred))
print(classification_report(y2,y_pred))
# Out:
# [[  71  149]
#  [  11 4209]]
#               precision    recall  f1-score   support
#
#       attack       0.87      0.32      0.47       220
#       normal       0.97      1.00      0.98      4220
#
#     accuracy                           0.96      4440
#    macro avg       0.92      0.66      0.73      4440
# weighted avg       0.96      0.96      0.96      4440

# %%
data = pd.read_csv("../data/guardian/knn_model/final_files/8598117027-100-train.csv")

x = data.iloc[:,1:]
y = data.iloc[:,0:1].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

n_neighbors = 11
neigh = KNeighborsClassifier(n_neighbors, weights='distance')
neigh.fit(X_train, y_train)
y_pred = neigh.predict(x)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
# Out:
# [[  878     2]
#  [    3 16857]]
#               precision    recall  f1-score   support
#
#       attack       1.00      1.00      1.00       880
#       normal       1.00      1.00      1.00     16860
#
#     accuracy                           1.00     17740
#    macro avg       1.00      1.00      1.00     17740
# weighted avg       1.00      1.00      1.00     17740

# %%
data2 = pd.read_csv("../data/guardian/knn_model/final_files/8598117027-100.csv")

x2 = data2.iloc[:,1:]
y2 = data2.iloc[:,0:1]

y_pred = neigh.predict(x2)
print(confusion_matrix(y2,y_pred))
# Use zero_division parameter to handle undefined metrics warning
print(classification_report(y2, y_pred, zero_division=1))
# Out:
# [[  94  126]
#  [  12 4208]]
#               precision    recall  f1-score   support
#
#       attack       0.89      0.43      0.58       220
#       normal       0.97      1.00      0.98      4220
#
#     accuracy                           0.97      4440
#    macro avg       0.93      0.71      0.78      4440
# weighted avg       0.97      0.97      0.96      4440

# %%
data = pd.read_csv("../data/guardian/knn_model/final_files/1772246172-100.csv")

x = data.iloc[:,1:]
y = data.iloc[:,0:1].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)
n_neighbors = 11
neigh = KNeighborsClassifier(n_neighbors, weights='distance')
neigh.fit(X_train, y_train)
y_pred = neigh.predict(x)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
# Out:
# [[  696     4]
#  [    1 13489]]
#               precision    recall  f1-score   support
#
#       attack       1.00      0.99      1.00       700
#       normal       1.00      1.00      1.00     13490
#
#     accuracy                           1.00     14190
#    macro avg       1.00      1.00      1.00     14190
# weighted avg       1.00      1.00      1.00     14190

# %%
data2 = pd.read_csv("../data/guardian/knn_model/test1772246172-100.csv")

x2 = data2.iloc[:,1:]
y2 = data2.iloc[:,0:1]

y_pred = neigh.predict(x2)
print(confusion_matrix(y2,y_pred))
# Use zero_division parameter to handle undefined metrics warning
print(classification_report(y2, y_pred, zero_division=1))
# Out:
# [[  92  128]
#  [   9 4211]]
#               precision    recall  f1-score   support
#
#       attack       0.91      0.42      0.57       220
#       normal       0.97      1.00      0.98      4220
#
#     accuracy                           0.97      4440
#    macro avg       0.94      0.71      0.78      4440
# weighted avg       0.97      0.97      0.96      4440

# %%
data = pd.read_csv("../data/guardian/knn_model/final_files/5327442248-100.csv")

x = data.iloc[:,1:]
y = data.iloc[:,0:1].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)
n_neighbors = 11
neigh = KNeighborsClassifier(n_neighbors, weights='distance')
neigh.fit(X_train, y_train)
y_pred = neigh.predict(x)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
# Out:
# [[4872    3]
#  [  14 5836]]
#               precision    recall  f1-score   support
#
#       attack       1.00      1.00      1.00      4875
#       normal       1.00      1.00      1.00      5850
#
#     accuracy                           1.00     10725
#    macro avg       1.00      1.00      1.00     10725
# weighted avg       1.00      1.00      1.00     10725

# %%
data2 = pd.read_csv("../data/guardian/knn_model/test5327442248-100.csv")

x2 = data2.iloc[:,1:]
y2 = data2.iloc[:,0:1]

y_pred = neigh.predict(x2)
print(confusion_matrix(y2,y_pred))
# Use zero_division parameter to handle undefined metrics warning
print(classification_report(y2, y_pred, zero_division=1))
# Out:
# [[ 509   11]
#  [ 744 9226]]
#               precision    recall  f1-score   support
#
#       attack       0.41      0.98      0.57       520
#       normal       1.00      0.93      0.96      9970
#
#     accuracy                           0.93     10490
#    macro avg       0.70      0.95      0.77     10490
# weighted avg       0.97      0.93      0.94     10490

# %%
data = pd.read_csv("../data/guardian/knn_model/final_files/8345714249-100.csv")
# training_9050782635-200
x = data.iloc[:,1:]
y = data.iloc[:,0:1].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)
n_neighbors = 11
neigh = KNeighborsClassifier(n_neighbors, weights='distance')
neigh.fit(X_train, y_train)
y_pred = neigh.predict(x)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
# Out:
# [[ 518    2]
#  [   0 9970]]
#               precision    recall  f1-score   support
#
#       attack       1.00      1.00      1.00       520
#       normal       1.00      1.00      1.00      9970
#
#     accuracy                           1.00     10490
#    macro avg       1.00      1.00      1.00     10490
# weighted avg       1.00      1.00      1.00     10490

# %%
data2 = pd.read_csv("../data/guardian/knn_model/test8345714249-100.csv")

x2 = data2.iloc[:,1:]
y2 = data2.iloc[:,0:1]

y_pred = neigh.predict(x2)
print(confusion_matrix(y2,y_pred))
# Use zero_division parameter to handle undefined metrics warning
print(classification_report(y2, y_pred, zero_division=1))
# Out:
# [[2105 2770]
#  [   8 5842]]
#               precision    recall  f1-score   support
#
#       attack       1.00      0.43      0.60      4875
#       normal       0.68      1.00      0.81      5850
#
#     accuracy                           0.74     10725
#    macro avg       0.84      0.72      0.71     10725
# weighted avg       0.82      0.74      0.71     10725

# %%
data = pd.read_csv("../data/guardian/knn_model/training_9050782635-200.csv")

x = data.iloc[:,1:]
y = data.iloc[:,0:1].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)
n_neighbors = 11
neigh = KNeighborsClassifier(n_neighbors, weights='distance')
neigh.fit(X_train, y_train)
y_pred = neigh.predict(x)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
# Out:
# [[  835     5]
#  [    2 15958]]
#               precision    recall  f1-score   support
#
#       attack       1.00      0.99      1.00       840
#       normal       1.00      1.00      1.00     15960
#
#     accuracy                           1.00     16800
#    macro avg       1.00      1.00      1.00     16800
# weighted avg       1.00      1.00      1.00     16800

# %%
data2 = pd.read_csv("../data/guardian/knn_model/test_9050782635-200.csv")
x2 = data2.iloc[:,1:]
y2 = data2.iloc[:,0:1]

y_pred = neigh.predict(x2)
print(confusion_matrix(y2,y_pred))
# Use zero_division parameter to handle undefined metrics warning
print(classification_report(y2, y_pred, zero_division=1))
# Out:
# [[ 105  105]
#  [   6 3994]]
#               precision    recall  f1-score   support
#
#       attack       0.95      0.50      0.65       210
#       normal       0.97      1.00      0.99      4000
#
#     accuracy                           0.97      4210
#    macro avg       0.96      0.75      0.82      4210
# weighted avg       0.97      0.97      0.97      4210

# %%
data = pd.read_csv("../data/guardian/knn_model/6038796523-300-5.csv")

x = data.iloc[:,1:]
y = data.iloc[:,0:1].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)
n_neighbors = 11
neigh = KNeighborsClassifier(n_neighbors, weights='distance')
neigh.fit(X_train, y_train)
y_pred = neigh.predict(x)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
# Out:
# [[62]]
#               precision    recall  f1-score   support
#
#       attack       1.00      1.00      1.00        62
#
#     accuracy                           1.00        62
#    macro avg       1.00      1.00      1.00        62
# weighted avg       1.00      1.00      1.00        62

# %%
data2 = pd.read_csv("../data/guardian/knn_model/test_6038796523-300-5.csv")
x2 = data2.iloc[:,1:]
y2 = data2.iloc[:,0:1]

y_pred = neigh.predict(x2)
print(confusion_matrix(y2,y_pred))
# Use zero_division parameter to handle undefined metrics warning
print(classification_report(y2, y_pred, zero_division=1))
# Out:
# [[ 210    0]
#  [4000    0]]
#               precision    recall  f1-score   support
#
#       attack       0.05      1.00      0.10       210
#       normal       1.00      0.00      0.00      4000
#
#     accuracy                           0.05      4210
#    macro avg       0.52      0.50      0.05      4210
# weighted avg       0.95      0.05      0.00      4210

# %%
data = pd.read_csv("../data/guardian/knn_model/knn_training_8864816883-300-2.csv")

x = data.iloc[:,1:]
y = data.iloc[:,0:1].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)
n_neighbors = 11
neigh = KNeighborsClassifier(n_neighbors, weights='distance')
neigh.fit(X_train, y_train)
y_pred = neigh.predict(x)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
# Out:
# [[  831     9]
#  [    3 15957]]
#               precision    recall  f1-score   support
#
#       attack       1.00      0.99      0.99       840
#       normal       1.00      1.00      1.00     15960
#
#     accuracy                           1.00     16800
#    macro avg       1.00      0.99      1.00     16800
# weighted avg       1.00      1.00      1.00     16800

# %%
data2 = pd.read_csv("../data/guardian/knn_model/test_1conv_8864816883-300-2.csv")
x2 = data2.iloc[:,1:]
y2 = data2.iloc[:,0:1]

y_pred = neigh.predict(x2)
print(confusion_matrix(y2,y_pred))
# Use zero_division parameter to handle undefined metrics warning
print(classification_report(y2, y_pred, zero_division=1))
# Out:
# [[ 102  108]
#  [  10 3990]]
#               precision    recall  f1-score   support
#
#       attack       0.91      0.49      0.63       210
#       normal       0.97      1.00      0.99      4000
#
#     accuracy                           0.97      4210
#    macro avg       0.94      0.74      0.81      4210
# weighted avg       0.97      0.97      0.97      4210

# %%
data = pd.read_csv("../data/guardian/knn_model/knn_training_6362141245-300-1.csv")

x = data.iloc[:,1:]
y = data.iloc[:,0:1].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)
n_neighbors = 15
neigh = KNeighborsClassifier(n_neighbors, weights='distance')
neigh.fit(X_train, y_train)
y_pred = neigh.predict(x)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
# Out:
# [[  836     4]
#  [    3 15957]]
#               precision    recall  f1-score   support
#
#       attack       1.00      1.00      1.00       840
#       normal       1.00      1.00      1.00     15960
#
#     accuracy                           1.00     16800
#    macro avg       1.00      1.00      1.00     16800
# weighted avg       1.00      1.00      1.00     16800

# %%
data2 = pd.read_csv("../data/guardian/knn_model/test_6362141245-300-1.csv")
x2 = data2.iloc[:,1:]
y2 = data2.iloc[:,0:1]

y_pred = neigh.predict(x2)
print(confusion_matrix(y2,y_pred))
# Use zero_division parameter to handle undefined metrics warning
print(classification_report(y2, y_pred, zero_division=1))
# Out:
# [[ 111   99]
#  [  11 3989]]
#               precision    recall  f1-score   support
#
#       attack       0.91      0.53      0.67       210
#       normal       0.98      1.00      0.99      4000
#
#     accuracy                           0.97      4210
#    macro avg       0.94      0.76      0.83      4210
# weighted avg       0.97      0.97      0.97      4210

# %%
data = pd.read_csv("../data/guardian/knn_model/knn_training_2209158907-300.csv")

x = data.iloc[:,1:]
y = data.iloc[:,0:1].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)
n_neighbors = 11
neigh = KNeighborsClassifier(n_neighbors, weights='distance')
neigh.fit(X_train, y_train)
y_pred = neigh.predict(x)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
# Out:
# [[  834     6]
#  [    1 15959]]
#               precision    recall  f1-score   support
#
#       attack       1.00      0.99      1.00       840
#       normal       1.00      1.00      1.00     15960
#
#     accuracy                           1.00     16800
#    macro avg       1.00      1.00      1.00     16800
# weighted avg       1.00      1.00      1.00     16800

# %%
data2 = pd.read_csv("../data/guardian/knn_model/test_default2209158907-300.csv")
x2 = data2.iloc[:,1:]
y2 = data2.iloc[:,0:1]

y_pred = neigh.predict(x2)
print(confusion_matrix(y2,y_pred))
# Use zero_division parameter to handle undefined metrics warning
print(classification_report(y2, y_pred, zero_division=1))
# Out:
# [[  73  137]
#  [  16 3984]]
#               precision    recall  f1-score   support
#
#       attack       0.82      0.35      0.49       210
#       normal       0.97      1.00      0.98      4000
#
#     accuracy                           0.96      4210
#    macro avg       0.89      0.67      0.73      4210
# weighted avg       0.96      0.96      0.96      4210

# %%
#0.1Attack
data3 = pd.read_csv("../data/guardian/knn_model/knn_training_8331285754-300-1.csv")

x = data3.iloc[:,1:]
y = data3.iloc[:,0:1].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)
n_neighbors = 11
neigh = KNeighborsClassifier(n_neighbors, weights='distance')
neigh.fit(X_train, y_train)
y_pred = neigh.predict(x)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
# Out:
# [[  930     0]
#  [    0 17720]]
#               precision    recall  f1-score   support
#
#       attack       1.00      1.00      1.00       930
#       normal       1.00      1.00      1.00     17720
#
#     accuracy                           1.00     18650
#    macro avg       1.00      1.00      1.00     18650
# weighted avg       1.00      1.00      1.00     18650

# %%
data4 = pd.read_csv("../data/guardian/knn_model/test_1conv_8331285754-300-1.csv")
x2 = data4.iloc[:,1:]
y2 = data4.iloc[:,0:1]

y_pred = neigh.predict(x2)
print(confusion_matrix(y2,y_pred))
# Use zero_division parameter to handle undefined metrics warning
print(classification_report(y2, y_pred, zero_division=1))
# Out:
# [[ 228    2]
#  [   0 4440]]
#               precision    recall  f1-score   support
#
#       attack       1.00      0.99      1.00       230
#       normal       1.00      1.00      1.00      4440
#
#     accuracy                           1.00      4670
#    macro avg       1.00      1.00      1.00      4670
# weighted avg       1.00      1.00      1.00      4670

# %%
# 1Attack
data5 = pd.read_csv("../data/guardian/knn_model/knn_training_9387700481-300-1.csv")

x = data5.iloc[:,1:]
y = data5.iloc[:,0:1].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)
n_neighbors = 11
neigh = KNeighborsClassifier(n_neighbors, weights='distance')
neigh.fit(X_train, y_train)
y_pred = neigh.predict(x)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
# Out:
# [[  918     2]
#  [    2 17558]]
#               precision    recall  f1-score   support
#
#       attack       1.00      1.00      1.00       920
#       normal       1.00      1.00      1.00     17560
#
#     accuracy                           1.00     18480
#    macro avg       1.00      1.00      1.00     18480
# weighted avg       1.00      1.00      1.00     18480

# %%
data6 = pd.read_csv("../data/guardian/knn_model/test_1conv_9387700481-300-1.csv")
x2 = data6.iloc[:,1:]
y2 = data6.iloc[:,0:1]

y_pred = neigh.predict(x2)
print(confusion_matrix(y2,y_pred))
# Use zero_division parameter to handle undefined metrics warning
print(classification_report(y2, y_pred, zero_division=1))
# Out:
# [[ 194   36]
#  [   2 4398]]
#               precision    recall  f1-score   support
#
#       attack       0.99      0.84      0.91       230
#       normal       0.99      1.00      1.00      4400
#
#     accuracy                           0.99      4630
#    macro avg       0.99      0.92      0.95      4630
# weighted avg       0.99      0.99      0.99      4630

# %%
# 5Attack
data5 = pd.read_csv("../data/guardian/knn_model/knn_training_7117532915-300-4.csv")

x = data5.iloc[:,1:]
y = data5.iloc[:,0:1].values.ravel()

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)
n_neighbors = 11
neigh = KNeighborsClassifier(n_neighbors, weights='distance')
neigh.fit(X_train, y_train)
y_pred = neigh.predict(x)
print(confusion_matrix(y,y_pred))
print(classification_report(y,y_pred))
# Out:
# [[  873     7]
#  [    0 16860]]
#               precision    recall  f1-score   support
#
#       attack       1.00      0.99      1.00       880
#       normal       1.00      1.00      1.00     16860
#
#     accuracy                           1.00     17740
#    macro avg       1.00      1.00      1.00     17740
# weighted avg       1.00      1.00      1.00     17740

# %%
data6 = pd.read_csv("../data/guardian/knn_model/test_1conv_7117532915-300-4.csv")
x2 = data6.iloc[:,1:]
y2 = data6.iloc[:,0:1]

y_pred = neigh.predict(x2)
print(confusion_matrix(y2,y_pred))
# Use zero_division parameter to handle undefined metrics warning
print(classification_report(y2, y_pred, zero_division=1))
# Out:
# [[ 133   87]
#  [   5 4215]]
#               precision    recall  f1-score   support
#
#       attack       0.96      0.60      0.74       220
#       normal       0.98      1.00      0.99      4220
#
#     accuracy                           0.98      4440
#    macro avg       0.97      0.80      0.87      4440
# weighted avg       0.98      0.98      0.98      4440

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data setup
categories = ['Training', 'Evaluation']
attack = np.array([840, 210])
normal = np.array([16800 - 840, 4210 - 210])

# Bar setup
bar_width = 0.35
index = np.arange(len(categories))

plt.figure(figsize=(6, 6))  # Maintain figure size for clarity
bar_width = 0.4  # Reduce bar width to avoid overlapping and ensure clarity
index = np.arange(len(categories)) * 0.5  # Keep reduced distance between bars

# Plotting with adjusted settings to avoid overlapping
plt.bar(index, normal, bar_width, label='Normal', color='skyblue')
plt.bar(index, attack, bar_width, bottom=normal, label='Attack', color='orange')

# Adding labels, title, and customizing the x-axis
plt.xlabel('Dataset')
plt.ylabel('Number of Data Points')
plt.title('Distribution of Data Points in Training and Evaluation Sets (16800 total)')
plt.xticks(index, categories)
plt.legend()

# Adjusting annotations to match the new bar width and positions
for i, (na, at) in enumerate(zip(normal, attack)):
    plt.text(i * 0.5, na / 2, '%d' % na, ha='center', va='center', color='black')
    plt.text(i * 0.5, na + at / 2, '%d' % at, ha='center', va='center', color='black')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# # Data from the user's table
# models = ['Scenario 1', 'Scenario 2']
# metrics = ['Precision', 'Recall', 'Val_precision', 'Val_recall', 'F1', 'Computation Time']
# scenario_1_values = [0.99, 0.99, 0.80, 0.82, 0.81, 15605]  # Including computation time for Scenario 1
# scenario_2_values = [0.99, 0.99, 0.73, 0.84, 0.81, 22091]  # Including computation time for Scenario 2


# Data from the user's table
models = ['Scenario 1', 'Scenario 2']
metrics = ['Accuracy', 'Recall', 'F1', 'Val_accuracy', 'Val_recall', 'Computation Time']
scenario_1_values = [0.99, 0.99, 0.99, 0.90, 0.92, 15605]  # Including computation time for Scenario 1
scenario_2_values = [0.99, 0.99, 0.99, 0.83, 0.94, 22091]  # Including computation time for Scenario 2

# # Data from the user's table
# models = ['Scenario 1', 'Scenario 2']
# metrics = ['Accuracy', 'Recall', 'Val_accuracy', 'Val_recall', 'Computation Time']
# scenario_1_values = [0.99, 0.99, 0.90, 0.92, 15605]  # Including computation time for Scenario 1
# scenario_2_values = [0.99, 0.99, 0.83, 0.94, 22091]  # Including computation time for Scenario 2


bar_width = 0.35  # width of the bars
index = np.arange(len(metrics))  # the label locations

fig, ax = plt.subplots(figsize=(14, 6))  # Adjusted figure size for the additional metric

# Plotting the metrics except for computation time
bar1 = ax.bar(index[:-1] - bar_width/2, scenario_1_values[:-1], bar_width, label='Scenario 1', color='skyblue')
bar2 = ax.bar(index[:-1] + bar_width/2, scenario_2_values[:-1], bar_width, label='Scenario 2', color='green')

# Plotting computation time on a secondary axis
ax2 = ax.twinx()  # Create a second y-axis
bar3 = ax2.bar(index[-1] - bar_width/2, scenario_1_values[-1], bar_width, color='blue')
bar4 = ax2.bar(index[-1] + bar_width/2, scenario_2_values[-1], bar_width, color='orange')

# Adding labels, title, and customizing the x-axis
ax.set_xlabel('Metrics', fontsize=15)
ax.set_ylabel('Values', fontsize=15)
ax2.set_ylabel('Computation Time', fontsize=15)  # Label for the secondary y-axis
ax.set_title('Model Performance Metrics including Computation Time')
ax.set_xticks(index)
ax.set_xticklabels(metrics)
ax.legend(loc='upper center')

# Adding annotations to bars
def add_labels(bars, ax_used):
    for bar in bars:
        height = bar.get_height()
        ax_used.annotate('{:.2f}'.format(height),
                         xy=(bar.get_x() + bar.get_width() / 2, height),
                         xytext=(0, 3),  # 3 points vertical offset
                         textcoords="offset points",
                         ha='center', va='bottom')

add_labels(bar1, ax)
add_labels(bar2, ax)
# For computation time, you might want to format the annotation differently
add_labels(bar3, ax2)
add_labels(bar4, ax2)

# plt.savefig('high_quality_plot.pdf', format='pdf')  # Vector format, ideal for documents
plt.savefig('high_quality_plot.png', format='png', dpi=300)  # Raster format, high resolution

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.family"] = "Times New Roman"
# Data from the user's table
models = ['Scenario 1', 'Scenario 2']
metrics = ['Accuracy', 'Recall', 'Val_accuracy', 'Val_recall', 'Computation Time']
scenario_1_values = [0.99, 0.99, 0.90, 0.92, 15605]  # Including computation time for Scenario 1
scenario_2_values = [0.99, 0.99, 0.83, 0.94, 22091]  # Including computation time for Scenario 2

bar_width = 0.35  # width of the bars
index = np.arange(len(metrics))  # the label locations

# Increase the figure size for better clarity
fig, ax = plt.subplots(figsize=(18, 12))  # Adjusted figure size

# Plotting the metrics except for computation time
bar1 = ax.bar(index[:-1] - bar_width/2, scenario_1_values[:-1], bar_width, label='Scenario 1', color='skyblue')
bar2 = ax.bar(index[:-1] + bar_width/2, scenario_2_values[:-1], bar_width, label='Scenario 2', color='green')

# Plotting computation time on a secondary axis
ax2 = ax.twinx()  # Create a second y-axis for computation time
bar3 = ax2.bar(index[-1] - bar_width/2, scenario_1_values[-1], bar_width, color='blue')
bar4 = ax2.bar(index[-1] + bar_width/2, scenario_2_values[-1], bar_width, color='orange')

# Adding labels, title, and customizing the x-axis
ax.set_xlabel('Metrics', fontsize=32)
ax.set_ylabel('Values', fontsize=32)
ax2.set_ylabel('Computation Time', fontsize=32)  # Label for the secondary y-axis
ax.set_title('Model Performance Metrics including Computation Time', fontsize=32, pad=20)
ax.set_xticks(index)
ax.set_xticklabels(metrics, fontsize=24)
ax.legend(loc='upper center', fontsize=24)

# Customize y-axis ticks font size
ax.tick_params(axis='y', labelsize=32)
ax2.tick_params(axis='y', labelsize=32)
ax.tick_params(axis='x', labelsize=32)

# Adding annotations to bars
def add_labels(bars, ax_used, is_time=False):
    for bar in bars:
        height = bar.get_height()
        if is_time:
            ax_used.annotate(f'{int(height):,}',  # Format as integer with commas for large numbers
                             xy=(bar.get_x() + bar.get_width() / 2, height),
                             xytext=(0, 3),  # 3 points vertical offset
                             textcoords="offset points",
                             ha='center', va='bottom', fontsize=32)
        else:
            ax_used.annotate(f'{height:.2f}',
                             xy=(bar.get_x() + bar.get_width() / 2, height),
                             xytext=(0, 3),  # 3 points vertical offset
                             textcoords="offset points",
                             ha='center', va='bottom', fontsize=32)

# Add annotations with appropriate formatting
add_labels(bar1, ax)
add_labels(bar2, ax)
add_labels(bar3, ax2, is_time=True)  # Annotate with commas for computation time
add_labels(bar4, ax2, is_time=True)  # Annotate with commas for computation time

# Save the plot as a high-resolution PNG or a PDF if needed
plt.tight_layout()
plt.savefig('model_performance.png', format='png', dpi=300)  # Save as high-resolution PNG

plt.show()

# %%
# Data from the table snapshot
models = ['Scenario 1', 'Scenario 2', 'Default model']
precision = [0.99, 0.95, 0.89]
recall = [0.92, 0.90, 0.55]
f1 = [0.96, 0.93, 0.68]
true_positive = [142, 147, 101]
false_negative = [68, 63, 109]
true_negative = [3963, 3961, 3970]
false_positive = [37, 39, 30]

# Bar width
bar_width = 0.2

# Set position of bar on X axis
r1 = np.arange(len(precision))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Make the plot
plt.figure(figsize=(14, 8))

# Create precision, recall, and f1 score bars
plt.bar(r1, precision, color='skyblue', width=bar_width, edgecolor='grey', label='Accuracy')
plt.bar(r2, recall, color='green', width=bar_width, edgecolor='grey', label='Recall')
plt.bar(r3, f1, color='orange', width=bar_width, edgecolor='grey', label='F1 Score')

# Add labels
plt.xlabel('Models', fontweight='bold', fontsize=15)
plt.ylabel('Scores', fontweight='bold', fontsize=15)
plt.xticks([r + bar_width for r in range(len(precision))], models)

# Create legend & Show graphic
plt.legend()
plt.title('Comparison of Accuracy, Recall, and F1 Scores for Evaluation set')
plt.savefig('comparison1.png', format='png', dpi=300)  # Raster format, high resolution
plt.tight_layout()
plt.show()


# Now, let's plot the confusion matrix metrics
# plt.figure(figsize=(14, 8))

# # Create true positive, false negative, true negative, and false positive bars
# plt.bar(r1, true_positive, color='blue', width=bar_width, edgecolor='grey', label='True Positive')
# plt.bar(r2, false_negative, color='red', width=bar_width, edgecolor='grey', label='False Negative')
# plt.bar(r3, true_negative, color='green', width=bar_width, edgecolor='grey', label='True Negative')
# plt.bar(r1, false_positive, color='orange', width=bar_width, edgecolor='grey', label='False Positive', bottom=true_negative)

# # Add labels
# plt.xlabel('Models', fontweight='bold', fontsize=15)
# plt.ylabel('Counts', fontweight='bold', fontsize=15)
# plt.xticks([r + bar_width for r in range(len(precision))], models)

# # Create legend & Show graphic
# plt.legend()
# plt.title('Confusion Matrix Metrics Across Models')
# plt.tight_layout()
# plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the table snapshot
models = ['Scenario 1', 'Scenario 2', 'Default model']
precision = [0.89, 0.90, 0.82]
recall = [0.50, 0.54, 0.36]
f1 = [0.64, 0.67, 0.50]
true_positive = [142, 147, 101]
false_negative = [68, 63, 109]
true_negative = [3963, 3961, 3970]
false_positive = [37, 39, 30]

# Bar width
bar_width = 0.2

# Set position of bar on X axis
r1 = np.arange(len(precision))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Make the plot
plt.figure(figsize=(14, 8))

# Create precision, recall, and f1 score bars
plt.bar(r1, precision, color='skyblue', width=bar_width, edgecolor='grey', label='Accuracy')
plt.bar(r2, recall, color='green', width=bar_width, edgecolor='grey', label='Recall')
plt.bar(r3, f1, color='orange', width=bar_width, edgecolor='grey', label='F1 Score')

# Add labels
plt.xlabel('Models', fontweight='bold', fontsize=15)
plt.ylabel('Scores', fontweight='bold', fontsize=15)
plt.xticks([r + bar_width for r in range(len(precision))], models)

# Create legend & Show graphic
plt.legend()
plt.title('Comparison of Accuracy, Recall, and F1 Scores for KNN (default settings)')
plt.savefig('knn_default.png', format='png', dpi=300)  # Raster format, high resolution
plt.tight_layout()
plt.show()

# Now, let's plot the confusion matrix metrics
plt.figure(figsize=(14, 8))

# # Create true positive, false negative, true negative, and false positive bars
# plt.bar(r1, true_positive, color='blue', width=bar_width, edgecolor='grey', label='True Positive')
# plt.bar(r2, false_negative, color='red', width=bar_width, edgecolor='grey', label='False Negative')
# plt.bar(r3, true_negative, color='green', width=bar_width, edgecolor='grey', label='True Negative')
# plt.bar(r1, false_positive, color='orange', width=bar_width, edgecolor='grey', label='False Positive', bottom=true_negative)

# # Add labels
# plt.xlabel('Models', fontweight='bold', fontsize=15)
# plt.ylabel('Counts', fontweight='bold', fontsize=15)
# plt.xticks([r + bar_width for r in range(len(precision))], models)

# # Create legend & Show graphic
# plt.legend()
# plt.title('Confusion Matrix Metrics Across Models')
# plt.tight_layout()
# plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the table snapshot
models = ['Scenario 1', 'Scenario 2', 'Default model']
precision = [0.79, 0.79, 0.77]
recall = [0.68, 0.70, 0.48]
f1 = [0.73, 0.74, 0.59]
true_positive = [142, 147, 101]
false_negative = [68, 63, 109]
true_negative = [3963, 3961, 3970]
false_positive = [37, 39, 30]

# Bar width
bar_width = 0.2

# Set position of bar on X axis
r1 = np.arange(len(precision))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Make the plot
plt.figure(figsize=(14, 8))

# Create precision, recall, and f1 score bars
plt.bar(r1, precision, color='skyblue', width=bar_width, edgecolor='grey', label='Accuracy')
plt.bar(r2, recall, color='green', width=bar_width, edgecolor='grey', label='Recall')
plt.bar(r3, f1, color='orange', width=bar_width, edgecolor='grey', label='F1 Score')

# Add labels
plt.xlabel('Models', fontweight='bold', fontsize=15)
plt.ylabel('Scores', fontweight='bold', fontsize=15)
plt.xticks([r + bar_width for r in range(len(precision))], models)

# Create legend & Show graphic
plt.legend()
plt.title('Comparison of Accuracy, Recall, and F1 Scores for KNN (modified settings)')
plt.savefig('knn_modified.png', format='png', dpi=300)  # Raster format, high resolution
plt.tight_layout()
plt.show()

# Now, let's plot the confusion matrix metrics
plt.figure(figsize=(14, 8))

# # Create true positive, false negative, true negative, and false positive bars
# plt.bar(r1, true_positive, color='blue', width=bar_width, edgecolor='grey', label='True Positive')
# plt.bar(r2, false_negative, color='red', width=bar_width, edgecolor='grey', label='False Negative')
# plt.bar(r3, true_negative, color='green', width=bar_width, edgecolor='grey', label='True Negative')
# plt.bar(r1, false_positive, color='orange', width=bar_width, edgecolor='grey', label='False Positive', bottom=true_negative)

# # Add labels
# plt.xlabel('Models', fontweight='bold', fontsize=15)
# plt.ylabel('Counts', fontweight='bold', fontsize=15)
# plt.xticks([r + bar_width for r in range(len(precision))], models)

# # Create legend & Show graphic
# plt.legend()
# plt.title('Confusion Matrix Metrics Across Models')
# plt.tight_layout()
# plt.show()

# %%
from collections import Counter
#0.1Attack
# data = pd.read_csv("../data/guardian/knn_model/knn_training_8331285754-300-1.csv")
# data = pd.read_csv("../data/guardian/knn_model/test_1conv_8331285754-300-1.csv")
#1Attack
# data = pd.read_csv("../data/guardian/knn_model/knn_training_9387700481-300-1.csv")
# data = pd.read_csv("../data/guardian/knn_model/test_1conv_9387700481-300-1.csv")
#5Attack
# data = pd.read_csv("../data/guardian/knn_model/knn_training_7117532915-300-4.csv")
data = pd.read_csv("../data/guardian/knn_model/test_1conv_7117532915-300-4.csv")
#10Attack
# data = pd.read_csv("../data/guardian/knn_model/test_1conv_8864816883-300-2.csv")

# Make a copy of the DataFrame to keep the original data unchanged
df_copy = data.copy()

# Step 1: Calculate the median of each row and save it into a new column
df_copy['median'] = df_copy.median(axis=1)

# Step 2: Save the highest value of each row in a new column
df_copy['max_value'] = df_copy.max(axis=1)

# Step 3: Compute the distance between the highest value and median
df_copy['dist_median_max'] = df_copy['max_value'] - df_copy['median']

# Step 4: Write the function for conditional labeling
def conditional_label(row):
    if (row['median'] > 0.2 and row['dist_median_max'] > 0.2) or row['max_value'] > 0.5:
        return True
    else:
        return False

# Apply the function to each row
df_copy['label'] = df_copy.apply(conditional_label, axis=1)

# A helper function to process each batch
def process_batch(batch):
    # Count the number of TRUE values in the batch
    true_count = batch.sum()
    # Make a decision based on the count of TRUE values
    return "ATTACK" if true_count >  8 else "SAFE"

# Step 2 & 3: Process batches and make decisions
# Apply the function to each batch of 10 rows in the 'label' column
# Note: Adjust the batch size if necessary by changing '10' to another value
results = [process_batch(df_copy['label'][i:i+10]) for i in range(0, len(df_copy['label']), 10)]

# Step 4: Store results
# Here we just print the results, but you could also add them to your DataFrame or save them to a file
# print(results[0:88])
# print(results[0:22])
print(f'Among real attackes attack is: {results[0:22].count("ATTACK")}')
print(f'False attack is: {results[22:].count("ATTACK")}')
print(f'Total Attack is: {results.count("ATTACK")}')
print(f'Safe is: {results.count("SAFE")}')
print(f"Total number of accounts is {len(results)}, which includes {Counter(results)}.")
# Out:
# Among real attackes attack is: 16
# False attack is: 10
# Total Attack is: 26
# Safe is: 418
# Total number of accounts is 444, which includes Counter({'SAFE': 418, 'ATTACK': 26}).
# C:\Users\Shaygan\AppData\Local\Temp\ipykernel_18864\3583848924.py:18: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_copy['median'] = df_copy.median(axis=1)
# C:\Users\Shaygan\AppData\Local\Temp\ipykernel_18864\3583848924.py:21: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_copy['max_value'] = df_copy.max(axis=1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Sample data preparation
data = {
    "Models": ["0.1%", "1%", "5%", "10%"],
    "Accuracy": [1, 0.99, 0.96, 0.89],
    "Recall": [0.99, 0.84, 0.60, 0.50],
    "F1": [0.99, 0.91, 0.74, 0.64],
    "T_P": [228, 194, 133, 105],
    "F_N": [2, 36, 87, 105],
    "T_N": [4440, 4398, 4215, 3987],
    "F_P": [0, 2, 5, 13]
}

df = pd.DataFrame(data)

# Set the style
sns.set_style("whitegrid")

# Corrected approach to adjusting font sizes explicitly for axis labels, ticks, and titles

# Recreate the figure for the subplots with explicit font size adjustments
fig, axes = plt.subplots(figsize=(10, 6))

# Explicitly setting font sizes
tick_fontsize = 14  # Setting tick font size to 14 for better readability
label_fontsize = 16  # Setting label font size to 16 for titles and axes labels

# Bar plot for Accuracy, Recall, and F1 Score with explicit font size settings
sns.barplot(ax=axes, data=df.melt(id_vars=["Models"], value_vars=["Accuracy", "Recall", "F1"]),
            x="Models", y="value", hue="variable", palette=custom_palette)
axes.set_title("", fontsize=label_fontsize)
axes.set_ylabel("")  # Removing Y label
axes.set_xlabel("")  # Removing X label
axes.tick_params(axis='both', which='major', labelsize=tick_fontsize)
axes.set_ylim(0, 1.05)  # Extend y-axis to make room for annotations

plt.tight_layout()
# plt.savefig('comparison of different attacks.png', format='png', dpi=300)  # Raster format, high resolution
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 34
#      30 label_fontsize = 16  # Setting label font size to 16 for titles and axes labels
#      32 # Bar plot for Accuracy, Recall, and F1 Score with explicit font size settings
#      33 sns.barplot(ax=axes, data=df.melt(id_vars=["Models"], value_vars=["Accuracy", "Recall", "F1"]),
# ---> 34             x="Models", y="value", hue="variable", palette=custom_palette)
#      35 axes.set_title("", fontsize=label_fontsize)
#      36 axes.set_ylabel("")  # Removing Y label
#
# NameError: name 'custom_palette' is not defined

# %% [markdown]
# ##

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Sample data preparation
data = {
    "Models": ["0.1%", "1%", "5%", "10%"],
    "Accuracy": [1, 0.99, 0.96, 0.89],
    "Recall": [0.99, 0.84, 0.60, 0.50],
    "F1": [0.99, 0.91, 0.74, 0.64],
    "T_P": [228, 194, 133, 105],
    "F_N": [2, 36, 87, 105],
    "T_N": [4440, 4398, 4215, 3987],
    "F_P": [0, 2, 5, 13]
}

df = pd.DataFrame(data)

# Set the style
sns.set_style("whitegrid")

# Adjusting font sizes and making them bold
tick_fontsize_bold = 20  # Keeping the size but making them bold
label_fontsize_bold = 26  # Keeping the size but for titles and labels, make them bold as well

# Recreate the figure for the subplots with explicit font size adjustments
fig, ax = plt.subplots(figsize=(10, 6))

# Explicitly setting font sizes
tick_fontsize = 14  # Setting tick font size to 14 for better readability
label_fontsize = 16  # Setting label font size to 16 for titles and axes labels

# Bar plot with bold and larger axis numbers
sns.barplot(ax=ax, data=df.melt(id_vars=["Models"], value_vars=["Accuracy", "Recall", "F1"]),
            x="Models", y="value", hue="variable", palette=custom_palette)
ax.set_title("", fontsize=label_fontsize_bold)
ax.set_ylabel("")  # Removing Y label
ax.set_xlabel("")  # Removing X label
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize_bold, labelcolor='black', labelrotation=0, width=0.5)

# Make tick labels bold
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')

ax.set_ylim(0, 1.05)  # Extend y-axis to make room for annotations
ax.legend([],[], frameon=False)  # Removing the legend


plt.tight_layout()
plt.savefig('comparison of different attacks.png', format='png', dpi=500)  # Raster format, high resolution
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 36
#      32 label_fontsize = 16  # Setting label font size to 16 for titles and axes labels
#      34 # Bar plot with bold and larger axis numbers
#      35 sns.barplot(ax=ax, data=df.melt(id_vars=["Models"], value_vars=["Accuracy", "Recall", "F1"]),
# ---> 36             x="Models", y="value", hue="variable", palette=custom_palette)
#      37 ax.set_title("", fontsize=label_fontsize_bold)
#      38 ax.set_ylabel("")  # Removing Y label
#
# NameError: name 'custom_palette' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Sample data preparation
data = {
    "Models": ["0.1%", "1%", "5%", "10%"],
    "Accuracy": [1, 0.95, 0.82, 0.79],
    "Recall": [0.99, 0.92, 0.68, 0.68],
    "F1": [0.99, 0.94, 0.74, 0.74],
    "T_P": [228, 212, 150, 147],
    "F_N": [2, 18, 70, 63],
    "T_N": [4440, 4390, 4187, 3961],
    "F_P": [0, 10, 33, 39]
}

df = pd.DataFrame(data)

# Set the style
sns.set_style("whitegrid")

# Adjusting font sizes and making them bold
tick_fontsize_bold = 20  # Keeping the size but making them bold
label_fontsize_bold = 26  # Keeping the size but for titles and labels, make them bold as well

# Recreate the figure for the subplots with explicit font size adjustments
fig, ax = plt.subplots(figsize=(10, 6))

# Explicitly setting font sizes
tick_fontsize = 14  # Setting tick font size to 14 for better readability
label_fontsize = 16  # Setting label font size to 16 for titles and axes labels

# Bar plot with bold and larger axis numbers
sns.barplot(ax=ax, data=df.melt(id_vars=["Models"], value_vars=["Accuracy", "Recall", "F1"]),
            x="Models", y="value", hue="variable", palette=custom_palette)
ax.set_title("", fontsize=label_fontsize_bold)
ax.set_ylabel("")  # Removing Y label
ax.set_xlabel("")  # Removing X label
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize_bold, labelcolor='black', labelrotation=0, width=0.5)

# Make tick labels bold
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')

ax.set_ylim(0, 1.05)  # Extend y-axis to make room for annotations
ax.legend([],[], frameon=False)  # Removing the legend


plt.tight_layout()
plt.savefig('comparison of different attacks modified.png', format='png', dpi=500)  # Raster format, high resolution
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 36
#      32 label_fontsize = 16  # Setting label font size to 16 for titles and axes labels
#      34 # Bar plot with bold and larger axis numbers
#      35 sns.barplot(ax=ax, data=df.melt(id_vars=["Models"], value_vars=["Accuracy", "Recall", "F1"]),
# ---> 36             x="Models", y="value", hue="variable", palette=custom_palette)
#      37 ax.set_title("", fontsize=label_fontsize_bold)
#      38 ax.set_ylabel("")  # Removing Y label
#
# NameError: name 'custom_palette' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming 'percentage_changes' contains the percentage change data as previously calculated
data = {
    "Models": ["0.1%", "1%", "5%", "10%"],
    "Accuracy": [1, 0.99, 0.96, 0.89],
    "Recall": [0.99, 0.84, 0.60, 0.50],
    "F1": [0.99, 0.91, 0.74, 0.64]
    # "TP": [228, 194, 133, 105],
    # "FN": [2, 36, 87, 105],
    # "TN": [4440, 4398, 4215, 3987],
    # "FP": [0.01, 2, 5, 13]
}

data2 = {
    "Models": ["0.1%", "1%", "5%", "10%"],
    "Accuracy": [1, 0.95, 0.82, 0.79],
    "Recall": [0.99, 0.92, 0.68, 0.68],
    "F1": [0.99, 0.94, 0.74, 0.74]
    # "TP": [228, 212, 150, 147],
    # "FN": [2, 18, 70, 63],
    # "TN": [4440, 4390, 4187, 3961],
    # "FP": [0.01, 10, 33, 39]
}

# Convert data to DataFrames
df1 = pd.DataFrame(data).set_index("Models")
df2 = pd.DataFrame(data2).set_index("Models")

# Calculate the percentage change for each metric
percentage_changes = (df2 - df1) / df1 * 100
percentage_changes = percentage_changes.reset_index()

# Generating the heatmap with adjusted font sizes
plt.figure(figsize=(12, 6))
ax = sns.heatmap(percentage_changes.set_index('Models').T, annot=True, cmap='coolwarm', fmt='.2f',
                 linewidths=0.5, cbar_kws={"label": ""})

# Increase font size for the annotations by accessing them directly
for text in ax.texts + ax.get_xticklabels() + ax.get_yticklabels():
    text.set_size(20)
    text.set_weight("bold")

plt.title('', fontsize=20)
plt.xlabel('', fontsize=20)
plt.ylabel('', fontsize=20)
plt.xticks(rotation=0, fontsize=20)
plt.yticks(rotation=0, fontsize=20)
# plt.colorbar(ax.get_children()[0], label='Percentage Change (%)', fontsize=16)
plt.savefig('heat map comparison plain.png', format='png', dpi=500)  # Raster format, high resolution
plt.show()

# %%
# Assuming 'percentage_changes' contains the percentage change data as previously calculated
data = {
    "Models": ["Scenario 1", "Scenario 2", "Default Scenario [1]"],
    "Accuracy": [0.89, 0.90, 0.82],
    "Recall": [0.50, 0.54, 0.36],
    "F1": [0.64, 0.67, 0.50]
    # "TP": [105, 113, 76],
    # "FN": [105, 97, 134],
    # "TN": [3987, 3987, 3983],
    # "FP": [13, 13, 17]
}

data2 = {
    "Models": ["Scenario 1", "Scenario 2", "Default Scenario [1]"],
    "Accuracy": [0.79, 0.79, 0.77],
    "Recall": [0.68, 0.70, 0.48],
    "F1": [0.73, 0.74, 0.59]
    # "TP": [142, 147, 101]
    # "FN": [68, 63, 109],
    # "TN": [3963, 3961, 3970],
    # "FP": [37, 39, 30]
}

# Convert data to DataFrames
df1 = pd.DataFrame(data).set_index("Models")
df2 = pd.DataFrame(data2).set_index("Models")

# Calculate the percentage change for each metric
percentage_changes = (df2 - df1) / df1 * 100
percentage_changes = percentage_changes.reset_index()

# Generating the heatmap with adjusted font sizes
plt.figure(figsize=(12, 6))
ax = sns.heatmap(percentage_changes.set_index('Models').T, annot=True, cmap='coolwarm', fmt='.2f',
                 linewidths=0.5, cbar_kws={"label": ""})

# Increase font size for the annotations by accessing them directly
for text in ax.texts + ax.get_xticklabels() + ax.get_yticklabels():
    text.set_size(20)
    text.set_weight("bold")

plt.title('', fontsize=20)
plt.xlabel('', fontsize=20)
plt.ylabel('', fontsize=20)
plt.xticks(rotation=0, fontsize=20)
plt.yticks(rotation=0, fontsize=20)
# plt.colorbar(ax.get_children()[0], label='Percentage Change (%)', fontsize=16)
plt.savefig('Knn 1 heat map comparison.png', format='png', dpi=500)  # Raster format, high resolution
plt.show()

# %%
data = {
    "Models" : ['Scenario 1', 'Scenario 2', 'Default model'],
    "Accuracy" : [0.99, 0.95, 0.89],
    "Recall" : [0.92, 0.90, 0.55],
    "F1" : [0.96, 0.93, 0.68],
}
df = pd.DataFrame(data)

# Set the style
sns.set_style("whitegrid")

# Adjusting font sizes and making them bold
tick_fontsize_bold = 20  # Keeping the size but making them bold
label_fontsize_bold = 26  # Keeping the size but for titles and labels, make them bold as well

# Recreate the figure for the subplots with explicit font size adjustments
fig, ax = plt.subplots(figsize=(10, 6))

# Explicitly setting font sizes
tick_fontsize = 14  # Setting tick font size to 14 for better readability
label_fontsize = 16  # Setting label font size to 16 for titles and axes labels

# Bar plot with bold and larger axis numbers
sns.barplot(ax=ax, data=df.melt(id_vars=["Models"], value_vars=["Accuracy", "Recall", "F1"]),
            x="Models", y="value", hue="variable", palette=custom_palette)
ax.set_title("", fontsize=label_fontsize_bold)
ax.set_ylabel("")  # Removing Y label
ax.set_xlabel("")  # Removing X label
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize_bold, labelcolor='black', labelrotation=0, width=0.5)

# Make tick labels bold
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')

ax.set_ylim(0, 1.05)  # Extend y-axis to make room for annotations
ax.legend([],[], frameon=False)  # Removing the legend


plt.tight_layout()
plt.savefig('comparison1.png', format='png', dpi=500)  # Raster format, high resolution
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 25
#      21 label_fontsize = 16  # Setting label font size to 16 for titles and axes labels
#      23 # Bar plot with bold and larger axis numbers
#      24 sns.barplot(ax=ax, data=df.melt(id_vars=["Models"], value_vars=["Accuracy", "Recall", "F1"]),
# ---> 25             x="Models", y="value", hue="variable", palette=custom_palette)
#      26 ax.set_title("", fontsize=label_fontsize_bold)
#      27 ax.set_ylabel("")  # Removing Y label
#
# NameError: name 'custom_palette' is not defined

# %%
data = {
    "Models" : ['Scenario 1', 'Scenario 2', 'Default model'],
    "Accuracy" : [0.89, 0.90, 0.82],
    "Recall" : [0.50, 0.54, 0.36],
    "F1" : [0.64, 0.67, 0.50],
}
df = pd.DataFrame(data)

# Set the style
sns.set_style("whitegrid")

# Adjusting font sizes and making them bold
tick_fontsize_bold = 20  # Keeping the size but making them bold
label_fontsize_bold = 26  # Keeping the size but for titles and labels, make them bold as well

# Recreate the figure for the subplots with explicit font size adjustments
fig, ax = plt.subplots(figsize=(10, 6))

# Explicitly setting font sizes
tick_fontsize = 14  # Setting tick font size to 14 for better readability
label_fontsize = 16  # Setting label font size to 16 for titles and axes labels

# Bar plot with bold and larger axis numbers
sns.barplot(ax=ax, data=df.melt(id_vars=["Models"], value_vars=["Accuracy", "Recall", "F1"]),
            x="Models", y="value", hue="variable", palette=custom_palette)
ax.set_title("", fontsize=label_fontsize_bold)
ax.set_ylabel("")  # Removing Y label
ax.set_xlabel("")  # Removing X label
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize_bold, labelcolor='black', labelrotation=0, width=0.5)

# Make tick labels bold
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')

ax.set_ylim(0, 1.05)  # Extend y-axis to make room for annotations
ax.legend([],[], frameon=False)  # Removing the legend


plt.tight_layout()
plt.savefig('knn_default.png', format='png', dpi=500)  # Raster format, high resolution
plt.show()

# %%
# Sample data preparation
data = {
    "Models" : ['Scenario 1', 'Scenario 2', 'Default model'],
    "Accuracy" : [0.79, 0.79, 0.77],
    "Recall" : [0.68, 0.70, 0.48],
    "F1" : [0.73, 0.74, 0.59],
}

df = pd.DataFrame(data)

# Set the style
sns.set_style("whitegrid")

# Adjusting font sizes and making them bold
tick_fontsize_bold = 20  # Keeping the size but making them bold
label_fontsize_bold = 26  # Keeping the size but for titles and labels, make them bold as well

# Recreate the figure for the subplots with explicit font size adjustments
fig, ax = plt.subplots(figsize=(10, 6))

# Explicitly setting font sizes
tick_fontsize = 14  # Setting tick font size to 14 for better readability
label_fontsize = 16  # Setting label font size to 16 for titles and axes labels

# Bar plot with bold and larger axis numbers
sns.barplot(ax=ax, data=df.melt(id_vars=["Models"], value_vars=["Accuracy", "Recall", "F1"]),
            x="Models", y="value", hue="variable", palette=custom_palette)
ax.set_title("", fontsize=label_fontsize_bold)
ax.set_ylabel("")  # Removing Y label
ax.set_xlabel("")  # Removing X label
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize_bold, labelcolor='black', labelrotation=0, width=0.5)

# Make tick labels bold
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')

ax.set_ylim(0, 1.05)  # Extend y-axis to make room for annotations
ax.legend([],[], frameon=False)  # Removing the legend


plt.tight_layout()
plt.savefig('knn_modified.png', format='png', dpi=500)  # Raster format, high resolution
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 27
#      23 label_fontsize = 16  # Setting label font size to 16 for titles and axes labels
#      25 # Bar plot with bold and larger axis numbers
#      26 sns.barplot(ax=ax, data=df.melt(id_vars=["Models"], value_vars=["Accuracy", "Recall", "F1"]),
# ---> 27             x="Models", y="value", hue="variable", palette=custom_palette)
#      28 ax.set_title("", fontsize=label_fontsize_bold)
#      29 ax.set_ylabel("")  # Removing Y label
#
# NameError: name 'custom_palette' is not defined

# %%
models = ['Scenario 1', 'Scenario 2']
metrics = ['Precision', 'Recall', 'Val_precision', 'Val_recall', 'F1', 'Computation Time']
scenario_1_values = [0.99, 0.99, 0.80, 0.82, 0.81, 15605]  # Including computation time for Scenario 1
scenario_2_values = [0.99, 0.99, 0.73, 0.84, 0.81, 22091]  # Including computation time for Scenario 2

# Sample data preparation
data = {
    "Models" : ['Scenario 1', 'Scenario 2', 'Default model'],
    "Accuracy" : [0.79, 0.79, 0.77],
    "Recall" : [0.68, 0.70, 0.48],
    "F1" : [0.73, 0.74, 0.59],
}

df = pd.DataFrame(data)

# Set the style
sns.set_style("whitegrid")

# Adjusting font sizes and making them bold
tick_fontsize_bold = 20  # Keeping the size but making them bold
label_fontsize_bold = 26  # Keeping the size but for titles and labels, make them bold as well

# Recreate the figure for the subplots with explicit font size adjustments
fig, ax = plt.subplots(figsize=(10, 6))

# Explicitly setting font sizes
tick_fontsize = 14  # Setting tick font size to 14 for better readability
label_fontsize = 16  # Setting label font size to 16 for titles and axes labels

# Bar plot with bold and larger axis numbers
sns.barplot(ax=ax, data=df.melt(id_vars=["Models"], value_vars=["Accuracy", "Recall", "F1"]),
            x="Models", y="value", hue="variable", palette=custom_palette)
ax.set_title("", fontsize=label_fontsize_bold)
ax.set_ylabel("")  # Removing Y label
ax.set_xlabel("")  # Removing X label
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize_bold, labelcolor='black', labelrotation=0, width=0.5)

# Make tick labels bold
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')

ax.set_ylim(0, 1.05)  # Extend y-axis to make room for annotations
ax.legend([],[], frameon=False)  # Removing the legend


plt.tight_layout()
# plt.savefig('knn_modified.png', format='png', dpi=500)  # Raster format, high resolution
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 32
#      28 label_fontsize = 16  # Setting label font size to 16 for titles and axes labels
#      30 # Bar plot with bold and larger axis numbers
#      31 sns.barplot(ax=ax, data=df.melt(id_vars=["Models"], value_vars=["Accuracy", "Recall", "F1"]),
# ---> 32             x="Models", y="value", hue="variable", palette=custom_palette)
#      33 ax.set_title("", fontsize=label_fontsize_bold)
#      34 ax.set_ylabel("")  # Removing Y label
#
# NameError: name 'custom_palette' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the user's table
models = ['Scenario 1', 'Scenario 2']
metrics = ['Precision', 'Recall', 'Val_precision', 'Val_recall', 'F1', 'Computation Time']
scenario_1_values = [0.99, 0.99, 0.80, 0.82, 0.81, 15605]  # Including computation time for Scenario 1
scenario_2_values = [0.99, 0.99, 0.73, 0.84, 0.81, 22091]  # Including computation time for Scenario 2

bar_width = 0.35  # width of the bars
index = np.arange(len(metrics))  # the label locations

fig, ax = plt.subplots(figsize=(14, 6))  # Adjusted figure size for the additional metric

# Plotting the metrics except for computation time
bar1 = ax.bar(index[:-1] - bar_width/2, scenario_1_values[:-1], bar_width, label='Scenario 1', color='skyblue')
bar2 = ax.bar(index[:-1] + bar_width/2, scenario_2_values[:-1], bar_width, label='Scenario 2', color='green')

# Plotting computation time on a secondary axis
ax2 = ax.twinx()  # Create a second y-axis
bar3 = ax2.bar(index[-1] - bar_width/2, scenario_1_values[-1], bar_width, color='blue')
bar4 = ax2.bar(index[-1] + bar_width/2, scenario_2_values[-1], bar_width, color='darkgreen')

# Adjust font sizes and weights
ax.set_xlabel('', fontsize=20, fontweight='bold')  # Double size and bold
ax.set_ylabel('', fontsize=20, fontweight='bold')
# ax2.set_ylabel('', fontsize=20, fontweight='bold')  # Label for the secondary y-axis
ax.set_title('', fontsize=20, fontweight='bold')
ax.set_xticks(index)
ax.set_xticklabels(metrics, fontsize=20, fontweight='bold')  # Adjusted font size for readability
# ax.legend(loc='upper center', fontsize=20)

# Adding annotations to bars with adjusted size and weight
def add_labels(bars, ax_used):
    for bar in bars:
        height = bar.get_height()
        ax_used.annotate('{:.2f}'.format(height),
                         xy=(bar.get_x() + bar.get_width() / 2, height),
                         xytext=(0, 3),  # 3 points vertical offset
                         textcoords="offset points",
                         ha='center', va='bottom',
                         fontsize=20,  # Adjusted font size for readability
                         fontweight='bold')

add_labels(bar1, ax)
add_labels(bar2, ax)
# For computation time, you might want to format the annotation differently
add_labels(bar3, ax2)
add_labels(bar4, ax2)

plt.savefig('model_performance.png', format='png', dpi=700)  # Raster format, high resolution

plt.tight_layout()
plt.show()
